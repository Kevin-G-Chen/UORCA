# %%
packages <- c("edgeR",
              "limma",
              "tximport",
              "DESeq2",
             "janitor")

!pak::pkg_install(packages)
# Out:
# ✔ Updated metadata database: 1.39 MB in 1 file.
#
#
#
# ℹ Updating metadata database
#
# ✔ Updating metadata database ... done
#
#
#
#
#
# → Will install 2 packages.
#
# → Will download 2 CRAN packages (694.23 kB).
#
# + janitor     2.2.0  [bld][dl] (236.41 kB)
# + snakecase   0.11.1 [bld][dl] (457.82 kB)
#
# ✔ All system requirements are already installed.
#
#
#
# ℹ Getting 2 pkgs (694.23 kB)
#
# ✔ Got snakecase 0.11.1 (source) (457.82 kB)
#
# ✔ Got janitor 2.2.0 (source) (236.41 kB)
#
# ℹ Building snakecase 0.11.1
#
# ✔ Built snakecase 0.11.1 (1.5s)
#
# ✔ Installed snakecase 0.11.1  (1.1s)
#
# ℹ Building janitor 2.2.0
#
# ✔ Built janitor 2.2.0 (2.4s)
#
# ✔ Installed janitor 2.2.0  (75ms)
#
# ✔ 5 pkgs + 87 deps: kept 88, added 2, dld 2 (694.23 kB) [15.5s]
# Error in FUN(left): invalid argument type
# Traceback:
#
# 1. Ops.data.frame(pak::pkg_install(packages))
# 2. eval(f)
# 3. eval(f)

# %%
pak::pkg_install("clusterProfiler")
# Out:
# ℹ Loading metadata database
#
# ✔ Loading metadata database ... done
#
#
#
#
#
# → Will install 39 packages.
#
# → Will download 21 CRAN packages (25.40 MB), cached: 18 (2.49 MB).
#
# + ape               5.8       [bld][cmp]
# + aplot             0.2.3     [bld]
# + clusterProfiler   4.6.2     [bld]
# + cowplot           1.1.3     [bld][dl] (1.35 MB)
# + DOSE              3.24.2    [bld]
# + downloader        0.4       [bld][dl] (6.81 kB)
# + enrichplot        1.18.4    [bld]
# + fastmatch         1.1-4     [bld][cmp][dl] (15.22 kB)
# + fgsea             1.24.0    [bld][cmp]
# + ggforce           0.4.2     [bld][cmp][dl] (866.25 kB)
# + ggfun             0.1.5     [bld]
# + ggnewscale        0.5.0     [bld]
# + ggplotify         0.1.2     [bld][dl] (117.89 kB)
# + ggraph            2.2.1     [bld][cmp][dl] (3.44 MB)
# + ggrepel           0.9.5     [bld][cmp][dl] (151.03 kB)
# + ggtree            3.6.2     [bld]
# + GO.db             3.16.0    [bld]
# ...

# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("ggtree")
# Out:
# Bioconductor version '3.16' is out-of-date; the current release version '3.19'
#   is available with R version '4.4'; see https://bioconductor.org/install
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cloud.r-project.org
#
# Bioconductor version 3.16 (BiocManager 1.30.23), R 4.2.2 Patched (2022-11-10
#   r83330)
#
# Installing package(s) 'ggtree'
#
# Warning message in install.packages(...):
# “installation of package ‘ggtree’ had non-zero exit status”
# Installation paths not writeable, unable to update packages
#   path: /usr/lib/R/library
#   packages:
#     boot, class, cluster, codetools, foreign, KernSmooth, lattice, mgcv, nlme,
#     nnet, rpart, spatial, survival

# %%
packages <- c("boot",
              "class",
              "cluster",
              "codetools",
             "foreign",
             "KernSmooth",
             "lattice",
             "mgcv",
             "nlme",
             "nnet",
             "rpart",
             "spatial",
             "survival",
             "uuid")

!pak::pkg_install(packages)
# Out:
#
#
# → Will update 13 packages.
#
# → Will download 9 CRAN packages (3.04 MB), cached: 4 (7.95 MB).
#
# + boot       1.3-28.1 → 1.3-30  [bld][dl] (237.09 kB)
# + class      7.3-21   → 7.3-22  [bld][cmp][dl] (20.81 kB)
# + cluster    2.1.4    → 2.1.6   [bld][cmp][dl] (369.05 kB)
# + codetools  0.2-19   → 0.2-20  [bld][dl] (38.68 kB)
# + foreign    0.8-84   → 0.8-87  [bld][cmp]
# + KernSmooth 2.23-20  → 2.23-24 [bld][cmp]
# + lattice    0.20-45  → 0.22-6  [bld][cmp][dl] (598.58 kB)
# + mgcv       1.8-41   → 1.9-1   [bld][cmp][dl] (1.08 MB)
# + nlme       3.1-162  → 3.1-165 [bld][cmp]
# + nnet       7.3-18   → 7.3-19  [bld][cmp][dl] (29.15 kB)
# + rpart      4.1.19   → 4.1.23  [bld][cmp][dl] (618.02 kB)
# + spatial    7.3-16   → 7.3-17  [bld][cmp][dl] (44.66 kB)
# + survival   3.5-3    → 3.7-0   [bld][cmp]
#
#
#
# ℹ Getting 9 pkgs (3.04 MB), 4 (7.95 MB) cached
#
# ✔ Got KernSmooth 2.23-24 (source) (26.07 kB)
#
# ✔ Got class 7.3-22 (source) (20.81 kB)
#
# ...

# %%
!pak::pkg_install("GEOquery")
# Out:
# ℹ Loading metadata database
#
# ✔ Loading metadata database ... done
#
#
#
#
#
# → Will install 4 packages.
#
# → Will download 3 CRAN packages (771.97 kB), cached: 1 (0 B).
#
# + GEOquery      2.66.0 [bld]
# + R.methodsS3   1.8.2  [bld][dl] (24.13 kB)
# + R.oo          1.26.0 [bld][dl] (383.65 kB)
# + R.utils       2.12.3 [bld][dl] (364.19 kB)
#
# ✔ All system requirements are already installed.
#
#
#
# ℹ Getting 3 pkgs (771.97 kB), 1 cached
#
# ✔ Got R.methodsS3 1.8.2 (source) (24.13 kB)
#
# ✔ Got R.utils 2.12.3 (source) (364.19 kB)
#
# ✔ Got R.oo 1.26.0 (source) (383.65 kB)
#
# ✔ Got GEOquery 2.66.0 (source) (13.70 MB)
#
# ℹ Building R.methodsS3 1.8.2
#
# ✔ Built R.methodsS3 1.8.2 (888ms)
#
# ✔ Installed R.methodsS3 1.8.2  (75ms)
#
# ℹ Building R.oo 1.26.0
#
# ✔ Built R.oo 1.26.0 (3.1s)
#
# ✔ Installed R.oo 1.26.0  (75ms)
#
# ℹ Building R.utils 2.12.3
#
# ✔ Built R.utils 2.12.3 (5.7s)
#
# ✔ Installed R.utils 2.12.3  (77ms)
#
# ℹ Building GEOquery 2.66.0
#
# ...
