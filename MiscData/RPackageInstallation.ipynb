# %%
packages <- c("edgeR",
              "limma",
              "tximport",
              "DESeq2")

!pak::pkg_install(packages)
# Out:
# ℹ Loading metadata database
#
# ✔ Loading metadata database ... done
#
#
#
#
#
# → Will install 39 packages.
#
# → Will download 9 CRAN packages (14.78 MB), cached: 30 (11.21 MB).
#
# + annotate               1.76.0    [bld]
# + AnnotationDbi          1.60.2    [bld]
# + BH                     1.84.0-0  [bld][dl] (14.02 MB)
# + Biobase                2.58.0    [bld][cmp]
# + BiocGenerics           0.44.0    [bld]
# + BiocParallel           1.32.6    [bld][cmp]
# + Biostrings             2.66.0    [bld][cmp]
# + bitops                 1.0-8     [bld][cmp]
# + DelayedArray           0.24.0    [bld][cmp]
# + DESeq2                 1.38.3    [bld][cmp]
# + edgeR                  3.40.2    [bld][cmp]
# + formatR                1.14      [bld][dl] (96.08 kB)
# + futile.logger          1.4.3     [bld][dl] (17.46 kB)
# + futile.options         1.0.1     [bld][dl] (3.92 kB)
# + geneplotter            1.76.0    [bld]
# + GenomeInfoDb           1.34.9    [bld]
# ...

# %%
pak::pkg_install("clusterProfiler")
# Out:
#
#
# → Will install 39 packages.
#
# → Will download 21 CRAN packages (25.40 MB), cached: 18 (2.49 MB).
#
# + ape               5.8       [bld][cmp]
# + aplot             0.2.3     [bld]
# + clusterProfiler   4.6.2     [bld]
# + cowplot           1.1.3     [bld][dl] (1.35 MB)
# + DOSE              3.24.2    [bld]
# + downloader        0.4       [bld][dl] (6.81 kB)
# + enrichplot        1.18.4    [bld]
# + fastmatch         1.1-4     [bld][cmp][dl] (15.22 kB)
# + fgsea             1.24.0    [bld][cmp]
# + ggforce           0.4.2     [bld][cmp][dl] (866.25 kB)
# + ggfun             0.1.5     [bld]
# + ggnewscale        0.5.0     [bld]
# + ggplotify         0.1.2     [bld][dl] (117.89 kB)
# + ggraph            2.2.1     [bld][cmp][dl] (3.44 MB)
# + ggrepel           0.9.5     [bld][cmp][dl] (151.03 kB)
# + ggtree            3.6.2     [bld]
# + GO.db             3.16.0    [bld]
# + GOSemSim          2.24.0    [bld][cmp]
# + graphlayouts      1.1.1     [bld][cmp][dl] (3.83 MB)
# ...

# %%
Sys.setenv(R_LIBS_USER = "/home/myuser/R_libs")
pak::pkg_install("ggtree")
# Out:
#
#
# → Will install 1 package.
#
# → The package (0 B) is cached.
#
# + ggtree   3.6.2 [bld]
#
# ✔ All system requirements are already installed.
#
#
#
# ℹ No downloads are needed, 1 pkg is cached
#
# ℹ Building ggtree 3.6.2
#
# ✖ Failed to build ggtree 3.6.2 (1.7s)
# Error: ! error in pak subprocess
# Caused by error in `stop_task_build(state, worker)`:
# ! Failed to build source package ggtree.
# Traceback:
#
# 1. pak::pkg_install("ggtree")
# 2. remote(function(...) get("pkg_install_do_plan", asNamespace("pak"))(...),
#  .     list(proposal = NULL))
# 3. err$throw(res$error)

# %%
packages <- c("boot",
              "class",
              "cluster",
              "codetools",
             "foreign",
             "KernSmooth",
             "lattice",
             "mgcv",
             "nlme",
             "nnet",
             "rpart",
             "spatial",
             "survival",
             "uuid")

!pak::pkg_install(packages)
# Out:
#
#
#
#
# ℹ No downloads are needed
#
# ✔ 14 pkgs + 2 deps: kept 14 [1.7s]
# Error in FUN(left): invalid argument type
# Traceback:
#
# 1. Ops.data.frame(pak::pkg_install(packages))
# 2. eval(f)
# 3. eval(f)
