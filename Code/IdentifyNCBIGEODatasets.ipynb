# %%
# Modules
from openai import OpenAI
import os
import json
from tqdm import tqdm
import time
from Bio import Entrez
import numpy as np
import pandas as pd
from dotenv import load_dotenv
import instructor
from pydantic import BaseModel, Field
from typing import List
import asyncio
from concurrent.futures import ThreadPoolExecutor
from collections import Counter
# from typing import Literal
import statistics

# %%
load_dotenv('../.env')

Entrez.email = os.getenv('ENTREZ_EMAIL')
Entrez.api_key = os.getenv('ENTREZ_API_KEY')
openai_api_key = os.getenv('OPENAI_API_KEY')

# %%
# Test the OpenAI API key is working

client = OpenAI(
  api_key=openai_api_key,  # this is also the default, it can be omitted
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "What is the capital city of Victoria? Answer with only the name of the city",
        }
    ],
    model="gpt-4o-mini",
)

result = chat_completion.choices[0].message.content
print(result)
# Out:
# Melbourne

# %%
# Prepare dummy variables for testing purposes

user_query = "Identify datasets and samples which are relevant to exploring immunotherapies for lung cancer"
num_queries = 3

# %%
# Prepare functions for term extraction from research query

# Prepare output structures
## For term extraction from user query
class ExtractedTerms(BaseModel):
    extracted_terms: List[str] = Field(description="List of terms extracted from the query")
    expanded_terms: List[str] = Field(description="List of related terms generated from the extracted terms")

## For determining dataset relevance
class Assessment(BaseModel):
    ID: str
    RelevanceScore: int = Field(description="Score from 0 to 10, indicating relevance")
    Justification: str = Field(description="A brief explanation for the score")

class Assessments(BaseModel):
    assessments: List[Assessment]


# "Patch" the client?
client = instructor.patch(OpenAI(
    api_key=openai_api_key))

# Define function for term extraction 
def extract_terms(user_query: str) -> List[str]:
    prompt = f"""

## IDENTITY AND PURPOSE
You are an expert in literature searches of biological ideas. Your task is to identify biological term(s) from a query, and generate related terms for the purposes of generating a search query. 

## STEPS

- First, extract the biological term(s) from the input query. These should be specific and fall into one of the following categories:
1. Genes - Examples: BRCA1, TP53
2. Treatments/Methods - Examples: chemotherapy, CRISPR
3. Tissues/Cells - Examples: lung, hepatocytes
4. Diseases - Examples: Alzheimer's disease, lung cancer.

Do not fabricate items if no relevant term exists. Avoid general terms such as "disease" or "variant."

- Second, for each extracted biological term, generate two related terms. Make a considered effort to keep these terms in the same category as the original term. These are examples of an identified term, and possible relevant terms:
1. Genes: BRCA1 - Examples: BRCA2, oncogene
2. Treatments: Chemotherapy - Examples: radiotherapy, monoclonal antibody
3. Tissues/Cells: Lung - Examples: respiratory, alveoli
4. Diseases: Alzheimer's disease - Examples: dementia, amyloid plaque

## OUTPUT

Provide two lists:
1. Extracted terms: The primary terms identified directly from the query.
2. Expanded terms: The related terms generated from the extracted terms.
Do not include categories or justifications.

## INPUT
User query: {user_query}"""

    extracted_terms = client.chat.completions.create(
        model="gpt-4o-mini",
        temperature=1,
        response_model=ExtractedTerms,
        messages=[
            {"role": "system", "content": "You are an assistant that helps to extract and expand terms for better search results."},
            {"role": "user", "content": prompt}
        ]
    )
    
    print(f"Raw extracted terms: {extracted_terms.extracted_terms}")
    print(f"Raw expanded terms: {extracted_terms.expanded_terms}")
    
    all_terms = extracted_terms.extracted_terms + extracted_terms.expanded_terms
    terms_with_filter = [term + ' AND "gse"[Filter]' for term in all_terms]
    return terms_with_filter

# Extension - define function to perform term extraction multiple times
async def extract_terms_multiple(user_query: str, num_queries: int = 3) -> List[str]:
    async def single_extract():
        return extract_terms(user_query)
    
    tasks = [single_extract() for _ in range(num_queries)]
    results = await asyncio.gather(*tasks)
    
    # Flatten the list of lists and remove duplicates
    all_terms = list(set([term for sublist in results for term in sublist]))
    return all_terms

# Define function for performing search
def perform_search(term):
    search_handle = Entrez.esearch(db="gds", term=term, retmode="xml", retmax = 15) # CHANGE
    search_results = Entrez.read(search_handle)
    search_handle.close()
    return search_results

# Define function for extracting information from above search results
def extract_geo_info_batch(geo_ids):
    """
    Retrieve GEO information for a batch of GEO IDs.
    """
    ids_str = ",".join(geo_ids)
    handle = Entrez.esummary(db="gds", id=ids_str, retmode="xml")
    output = Entrez.read(handle)
    handle.close()

    data = []
    for geo_id, geo_data in zip(geo_ids, output):
        if isinstance(geo_data, dict):
            data.append({
                'ID': geo_id,
                'Title': geo_data.get('title', 'No title available'),
                'Summary': geo_data.get('summary', 'No summary available'),
                'Accession': geo_data.get('Accession', 'No accession available'),
                'Species': geo_data.get('taxon', 'No taxon available'),
                'Date': geo_data.get('PDAT', 'Date made public unknown')
            })
        else:
            data.append({'ID': geo_id, 'Title': 'Error', 'Summary': 'Unable to fetch data', 'Accession': 'Error'})

    return data

def create_geo_dataframe(geo_ids, batch_size=10):
    """Create a DataFrame from GEO search results using batch processing."""
    data = []
    for i in tqdm(range(0, len(geo_ids), batch_size), desc="Processing GEO IDs in batches"):
        batch_ids = geo_ids[i:i + batch_size]
        data.extend(extract_geo_info_batch(batch_ids))
        time.sleep(0.2)  # Be nice to NCBI servers
    return pd.DataFrame(data)


# Define function for determining relevance of datasets
def assess_relevance_batch(df, query, batch_size=10):
    results = []
    total_batches = (len(df) + batch_size - 1) // batch_size
    for i in tqdm(range(0, len(df), batch_size), desc="Determining dataset relevance", total=total_batches):
        batch = df.iloc[i:i+batch_size]
        prompt = f"""
## IDENTITY AND PURPOSE

You are a highly knowledgeable biologist tasked with identifying relevant datasets for a given research query. Your goal is to assess NCBI GEO datasets based on their titles and summaries, and determine their relevance to the research question at hand.

## STEPS

1. For each dataset, carefully analyze the provided title and summary.
2. Extract ALL biological concepts represented in the dataset, including but not limited to:
   - Genes and variants investigated (e.g., p53, BRCA1)
   - Species studied (e.g., Homo sapiens, Escherichia coli)
   - Sample sources (e.g., organoid cultures, human samples)
   - Diseases or phenotypes studied (e.g., Alzheimer's disease, lung cancer)
   - Cell types or tissues examined (e.g., lung tissue, neural progenitor cells)
   - Experimental techniques or methodologies used (e.g., RNA-seq, ChIP-seq)
3. Extract ALL biological concepts represented in the research query using the same categories.
4. Assign a relevance score from 0 to 10 in increments of 1, based solely on the provided information. 
   - Do not fabricate or assume information not explicitly stated about the dataset. 
   - If confirmed information about the dataset is POSSIBLY useful for the research question, view this favourably for determining dataset relevance. 
   - Note that the gene, disease, and cell type/tissue being studied are the most important in determining relevance. The other factors are considered minor aspects.
   - Use the following scoring guide:

   0: No relevance. All biological concepts (genes, species, samples, diseases, cell types, methods) are completely unrelated to the research query.
   1: Minimal relevance. One minor aspect is loosely related, but the overall focus is different.
   2: Low relevance. One major aspect aligns with the query, but other key elements differ significantly.
   3: Somewhat low relevance. Two aspects align, but critical elements are still mismatched.
   4: Moderate relevance. Multiple aspects align, but there are still significant differences in focus or approach.
   5: Moderately relevant. Most major aspects align, but there are some notable differences that may limit direct applicability.
   6: Relevant. All major aspects align, but there might be differences in specific genes, cell types, or methodologies that somewhat reduce direct applicability.
   7: Highly relevant. Very close alignment in all major aspects, with only minor differences that don't significantly impact applicability.
   8: Very highly relevant. Near-perfect alignment in all major aspects, with at most one or two minor differences.
   9: Extremely relevant. Perfect alignment in all major aspects, with at most one negligible difference.
   10: Perfectly relevant. The dataset appears to be an exact match for the research query in all aspects.

5. Provide a brief justification (3-4 sentences) for the assigned score, highlighting key similarities and differences.

## OUTPUT
For each dataset, provide a JSON object with the ID, relevance score, and justification. 
- The relevance score should be a number, with no other information.
- The justification should be a 4-5 sentence explanation for the relevance score. 

## HANDLING LIMITED INFORMATION
If the dataset title or summary lacks sufficient detail:
- Focus on the information that is available
- Do not make assumptions about missing information
- Assign a lower score if critical information is absent
- Note the lack of information in the justification

Remember, it's better to assign a lower score due to lack of information than to assume relevance without evidence.

Given the following datasets and query, determine if each dataset is relevant.
        Query: {query}
        Datasets:
        """
        for _, row in batch.iterrows():
            prompt += f"""
            ID: {row['ID']}
            Title: {row['Title']}
            Summary: {row['Summary']}
            Species: {row['Species']}
            """
        
        try:
            response = client.chat.completions.create(
                model="gpt-4o-mini",
                temperature=0.3,
                response_model=Assessments,
                messages=[
                    {"role": "system", "content": "You are a helpful assistant that determines dataset relevance and responds in JSON format."},
                    {"role": "user", "content": prompt}
                ],
                max_tokens=5000
            )
            results.extend([assessment.dict() for assessment in response.assessments])
        except Exception as e:
            results.extend([{"ID": row['ID'], "Relevance": "Error", "Justification": str(e)} for _, row in batch.iterrows()])
        time.sleep(1)  # Be nice to the API
    return results

# Extension - define function to assess relevance multiple times
async def assess_relevance_batch_multiple(df, query, num_queries: int = 3, batch_size=20):
    async def single_assess():
        return assess_relevance_batch(df, query, batch_size)
    
    tasks = [single_assess() for _ in range(num_queries)]
    results = await asyncio.gather(*tasks)
    
    # Collate results
    collated_results = {}
    for i, result_set in enumerate(results):
        for assessment in result_set:
            id = assessment['ID']
            if id not in collated_results:
                collated_results[id] = {'scores': [], 'justifications': []}
            collated_results[id]['scores'].append(assessment['RelevanceScore'])
            collated_results[id]['justifications'].append(assessment['Justification'])
    
    # Determine final relevance and format output
    final_results = []
    for id, data in collated_results.items():
        mean_score = statistics.mean(data['scores'])
        
        result = {
            'ID': id,
            'RelevanceScore': round(mean_score, 1),
        }
        
        # Add individual scores and justifications
        for i in range(num_queries):
            result[f'IndividualScore{i+1}'] = data['scores'][i] if i < len(data['scores']) else None
            result[f'Justification{i+1}'] = data['justifications'][i] if i < len(data['justifications']) else None
        
        final_results.append(result)
    
    return final_results

async def main(user_query):
    # Extract terms
    search_terms = await extract_terms_multiple(user_query)
    print("Extracted terms:", search_terms)

    # Perform Entrez search and remove duplicates
    geo_ids = set()  # Use a set to automatically remove duplicates
    for term in search_terms:
        search_results = perform_search(term)
        geo_ids.update(search_results.get('IdList', []))  # Update the set with new IDs
    if not geo_ids:
        return pd.DataFrame({'Error': ["No results found for the extracted terms"]})

    # Convert set back to list
    geo_ids = list(geo_ids)

    # Create DataFrame with GEO information
    df = create_geo_dataframe(geo_ids)

    # Assess relevance
    relevance_results = await assess_relevance_batch_multiple(df, user_query, num_queries=num_queries) # Currently have this at 3
    relevance_df = pd.DataFrame(relevance_results)

    # Merge results
    df['ID'] = df['ID'].astype(str)
    relevance_df['ID'] = relevance_df['ID'].astype(str)
    result_df = df.merge(relevance_df, on='ID', how='left')

    # Dynamically create the desired order of columns
    base_columns = ['ID', 'Title', 'Summary', 'Species', 'Accession', 'Date', 'RelevanceScore']
    score_columns = [f'IndividualScore{i+1}' for i in range(num_queries)]
    justification_columns = [f'Justification{i+1}' for i in range(num_queries)]
    desired_order = base_columns + score_columns + justification_columns

    # Reorder columns
    result_df = result_df[desired_order]

    # Reset index
    result_df = result_df.reset_index(drop=True)

    return result_df

# %%
# Test case - term extraction
search_terms = await (extract_terms_multiple(user_query))
print(search_terms)
# Out:
# Raw extracted terms: ['immunotherapies', 'lung cancer']
# Raw expanded terms: ['checkpoint inhibitors', 'non-small cell lung cancer', 'immune response', 'lung carcinoma']
# Raw extracted terms: ['immunotherapies', 'lung cancer']
# Raw expanded terms: ['checkpoint inhibitors', 'non-small cell lung cancer', 'CAR T-cell therapy', 'small cell lung cancer']
# Raw extracted terms: ['immunotherapies', 'lung cancer']
# Raw expanded terms: ['checkpoint inhibitors', 'non-small cell lung cancer', 'CAR T-cell therapy', 'lung carcinoma']
# ['immunotherapies AND "gse"[Filter]', 'non-small cell lung cancer AND "gse"[Filter]', 'CAR T-cell therapy AND "gse"[Filter]', 'checkpoint inhibitors AND "gse"[Filter]', 'small cell lung cancer AND "gse"[Filter]', 'lung carcinoma AND "gse"[Filter]', 'immune response AND "gse"[Filter]', 'lung cancer AND "gse"[Filter]']

# %%
# Test case - performing search
geo_ids = []
for term in tqdm(search_terms, "Performing search for extracted terms"):
    search_results = perform_search(term)
    geo_ids.extend(search_results.get('IdList', []))
# Out:
# Performing search for extracted terms: 100%|██████████| 8/8 [00:08<00:00,  1.12s/it]

# %%
# Test case - create data frame out of search results
df = create_geo_dataframe(geo_ids)
df # Jupyter is quite nice, I don't need to specify some specific function. Just this gives good output.
# Out:
# Processing GEO IDs in batches: 100%|██████████| 4/4 [00:07<00:00,  1.92s/it]
#            ID                                              Title  \
# 0   200269394  Long-lived central memory gamma delta T cells ...
# 1   200261624  Gene expression profile of all CD4 T cells fro...
# 2   200270741  Ceramide metabolism alterations contribute to ...
# 3   200270740  Ceramide metabolism alterations contribute to ...
# 4   200270084  Genome-wide Methylation Patterns in Primary Uv...
# 5   200239389  Prolyl hydroxylase domain enzyme PHD2 inhibits...
# 6   200272045  Identification of mutant KRAS-related genes as...
# 7   200269782  Defective N-Glycosylation of IL6 Induces Metas...
# 8   200218225  CRISPR screen of radiation resistant genes in ...
# 9   200234818  Faecalibaterium prausnitzii strain EXL01 boost...
# 10  200272474  SUMOylation inhibition potentiates CAR T activ...
# 11  200272300  SUMOylation inhibition potentiates CAR T activ...
# 12  200265937  Analysis of CD70 wild type or CD70 knock out C...
# 13  200227435  Analysis of CD70 wild type or CD70 knock out C...
# 14  200265904  GLUT1 overexpression enhances CAR T cell metab...
# 15  200270741  Ceramide metabolism alterations contribute to ...
# 16  200270740  Ceramide metabolism alterations contribute to ...
# 17  200233098  STAT3 inhibition permits epigenetic reprogramm...
# 18  200233097  STAT3 inhibition permits epigenetic reprogramm...
# 19  200233096  STAT3 inhibition permits epigenetic reprogramm...
# 20  200246354  GCN2 is a determinant of the response to WEE1 ...
# 21  200269746  Detecting small cell transformation in patient...
# 22  200249362  Non-Canonical BAF and mSWI/SNF Regulates POU2F...
# 23  200249258  Mammalian SWI/SNF complex activity regulates P...
# 24  200242843                  microarray in SCLC transformation
# 25  200271368  RNA-seq of live cell 3-D models with engineere...
# 26  200267490  Expression changes in respiratory epithelial c...
# 27  200230874  The DNA-repair protein APE1 contributes with h...
# 28  200229792  Cancer cell stiffening via CoQ10 and UBIAD1 re...
# 29  200270333  Methionine Restriction Reduces Lung Cancer Pro...
# 30  200269394  Long-lived central memory gamma delta T cells ...
# 31  200267811  Effect of knockdown of GRP94 on gene expressio...
# 32  200261624  Gene expression profile of all CD4 T cells fro...
# 33  200249265  Transcriptomics of BMDM treated with PTEN in t...
# 34  200241625  Loss of Elp3 impairs the immune response to he...
# 35  200271368  RNA-seq of live cell 3-D models with engineere...
# 36  200267325  RNA profiling of CSF resident macrophages and ...
# 37  200270333  Methionine Restriction Reduces Lung Cancer Pro...
# 38  200239389  Prolyl hydroxylase domain enzyme PHD2 inhibits...
# 39  200272045  Identification of mutant KRAS-related genes as...
#
#                                               Summary  Accession  \
# 0   The involvement of γδ TCR-bearing lymphocytes ...  GSE269394
# 1   The discovery of naïve T cell transcriptional ...  GSE261624
# 2   Introduction: Advanced cutaneous melanoma is a...  GSE270741
# 3   Introduction: Advanced cutaneous melanoma is a...  GSE270740
# 4   Despite studies highlighting the prognostic ut...  GSE270084
# 5   Prolyl hydroxylase domain protein 2 (PHD2) is ...  GSE239389
# 6   Oncogenic KRAS is found in more than 25% of lu...  GSE272045
# 7   The biological consequences of various IL-6 gl...  GSE269782
# 8   Radiotherapy is an important treatment for non...  GSE218225
# 9   Gut microbiota impacts responses to immune che...  GSE234818
# 10  Chimeric antigen receptor (CAR)-T cell therapy...  GSE272474
# 11  Chimeric antigen receptor (CAR)-T cell therapy...  GSE272300
# 12  CD70 is an attractive target for chimeric anti...  GSE265937
# 13  CD70 is an attractive target for chimeric anti...  GSE227435
# 14  The tumor microenvironment presents many obsta...  GSE265904
# 15  Introduction: Advanced cutaneous melanoma is a...  GSE270741
# 16  Introduction: Advanced cutaneous melanoma is a...  GSE270740
# 17  Cultured acute myeloid leukemia (AML) blasts c...  GSE233098
# 18  Cultured acute myeloid leukemia (AML) blasts c...  GSE233097
# 19  Cultured acute myeloid leukemia (AML) blasts c...  GSE233096
# 20  Patients with small-cell lung cancer (SCLC) ar...  GSE246354
# 21  Histologic transformation to small cell lung c...  GSE269746
# 22  ~12% of SCLCs are marked by the lineage transc...  GSE249362
# 23  Small cell lung cancers (SCLC) are comprised o...  GSE249258
# 24  The histological transformation of lung adenoc...  GSE242843
# 25  An experimental system was designed to screen ...  GSE271368
# 26  TGF-β1 is involved in various biological proce...  GSE267490
# 27  The base excision repair (BER) Apurinic/apyrim...  GSE230874
# 28  Here, we discovered that CoQ10 and its biosynt...  GSE229792
# 29  Methionine restriction sensitizes A549 cells w...  GSE270333
# 30  The involvement of γδ TCR-bearing lymphocytes ...  GSE269394
# 31  Anoikis resistance allows cancer cells to avoi...  GSE267811
# 32  The discovery of naïve T cell transcriptional ...  GSE261624
# 33  PTEN binds to and regulates polarization of TA...  GSE249265
# 34  Intestinal tuft cells are critical in anti-hel...  GSE241625
# 35  An experimental system was designed to screen ...  GSE271368
# 36  We investigated the functional effect of dura-...  GSE267325
# 37  Methionine restriction sensitizes A549 cells w...  GSE270333
# 38  Prolyl hydroxylase domain protein 2 (PHD2) is ...  GSE239389
# 39  Oncogenic KRAS is found in more than 25% of lu...  GSE272045
#
#          Species        Date
# 0   Mus musculus  2024/07/25
# 1   Mus musculus  2024/07/25
# 2   Homo sapiens  2024/07/24
# 3   Homo sapiens  2024/07/24
# 4   Homo sapiens  2024/07/24
# 5   Homo sapiens  2024/07/17
# 6   Homo sapiens  2024/07/16
# 7   Homo sapiens  2024/07/16
# 8   Homo sapiens  2024/07/12
# 9   Mus musculus  2024/07/10
# 10  Homo sapiens  2024/07/18
# 11  Homo sapiens  2024/07/18
# 12  Homo sapiens  2024/06/17
# 13  Homo sapiens  2024/06/17
# 14  Homo sapiens  2024/05/30
# 15  Homo sapiens  2024/07/24
# 16  Homo sapiens  2024/07/24
# 17  Mus musculus  2024/07/23
# 18  Mus musculus  2024/07/23
# 19  Mus musculus  2024/07/23
# 20  Homo sapiens  2024/07/16
# 21  Homo sapiens  2024/06/20
# 22  Homo sapiens  2024/06/14
# 23  Homo sapiens  2024/06/14
# 24  Homo sapiens  2024/06/12
# 25  Homo sapiens  2024/07/25
# 26  Homo sapiens  2024/07/24
# 27  Homo sapiens  2024/07/24
# 28  Homo sapiens  2024/07/23
# 29  Homo sapiens  2024/07/19
# 30  Mus musculus  2024/07/25
# 31  Homo sapiens  2024/07/25
# 32  Mus musculus  2024/07/25
# 33  Mus musculus  2024/07/25
# 34  Mus musculus  2024/07/25
# 35  Homo sapiens  2024/07/25
# 36  Mus musculus  2024/07/24
# 37  Homo sapiens  2024/07/19
# 38  Homo sapiens  2024/07/17
# 39  Homo sapiens  2024/07/16

# %%
# Test case - assessing dataset relevances

relevance_results = await assess_relevance_batch_multiple(df, user_query, num_queries=num_queries) # Currently have this at 3
relevance_df = pd.DataFrame(relevance_results)

# Merge results
df['ID'] = df['ID'].astype(str)
relevance_df['ID'] = relevance_df['ID'].astype(str)
result_df = df.merge(relevance_df, on='ID', how='left')

# Dynamically create the desired order of columns
base_columns = ['ID', 'Title', 'Summary', 'Species', 'Accession', 'Date', 'RelevanceScore']
score_columns = [f'IndividualScore{i+1}' for i in range(num_queries)]
justification_columns = [f'Justification{i+1}' for i in range(num_queries)]
desired_order = base_columns + score_columns + justification_columns

# Reorder columns
result_df = result_df[desired_order]

# Reset index
result_df = result_df.reset_index(drop=True)

result_df # Based on the output I'm assuming the token limit is too low
# Out:
# Determining dataset relevance: 100%|██████████| 2/2 [00:38<00:00, 19.16s/it]
# Determining dataset relevance: 100%|██████████| 2/2 [00:43<00:00, 21.96s/it]
# Determining dataset relevance: 100%|██████████| 2/2 [00:45<00:00, 22.91s/it]
#            ID                                              Title  \
# 0   200269394  Long-lived central memory gamma delta T cells ...
# 1   200261624  Gene expression profile of all CD4 T cells fro...
# 2   200270741  Ceramide metabolism alterations contribute to ...
# 3   200270740  Ceramide metabolism alterations contribute to ...
# 4   200270084  Genome-wide Methylation Patterns in Primary Uv...
# 5   200239389  Prolyl hydroxylase domain enzyme PHD2 inhibits...
# 6   200272045  Identification of mutant KRAS-related genes as...
# 7   200269782  Defective N-Glycosylation of IL6 Induces Metas...
# 8   200218225  CRISPR screen of radiation resistant genes in ...
# 9   200234818  Faecalibaterium prausnitzii strain EXL01 boost...
# 10  200272474  SUMOylation inhibition potentiates CAR T activ...
# 11  200272300  SUMOylation inhibition potentiates CAR T activ...
# 12  200265937  Analysis of CD70 wild type or CD70 knock out C...
# 13  200227435  Analysis of CD70 wild type or CD70 knock out C...
# 14  200265904  GLUT1 overexpression enhances CAR T cell metab...
# 15  200270741  Ceramide metabolism alterations contribute to ...
# 16  200270740  Ceramide metabolism alterations contribute to ...
# 17  200233098  STAT3 inhibition permits epigenetic reprogramm...
# 18  200233097  STAT3 inhibition permits epigenetic reprogramm...
# 19  200233096  STAT3 inhibition permits epigenetic reprogramm...
# 20  200246354  GCN2 is a determinant of the response to WEE1 ...
# 21  200269746  Detecting small cell transformation in patient...
# 22  200249362  Non-Canonical BAF and mSWI/SNF Regulates POU2F...
# 23  200249258  Mammalian SWI/SNF complex activity regulates P...
# 24  200242843                  microarray in SCLC transformation
# 25  200271368  RNA-seq of live cell 3-D models with engineere...
# 26  200267490  Expression changes in respiratory epithelial c...
# 27  200230874  The DNA-repair protein APE1 contributes with h...
# 28  200229792  Cancer cell stiffening via CoQ10 and UBIAD1 re...
# 29  200270333  Methionine Restriction Reduces Lung Cancer Pro...
# 30  200269394  Long-lived central memory gamma delta T cells ...
# 31  200267811  Effect of knockdown of GRP94 on gene expressio...
# 32  200261624  Gene expression profile of all CD4 T cells fro...
# 33  200249265  Transcriptomics of BMDM treated with PTEN in t...
# 34  200241625  Loss of Elp3 impairs the immune response to he...
# 35  200271368  RNA-seq of live cell 3-D models with engineere...
# 36  200267325  RNA profiling of CSF resident macrophages and ...
# 37  200270333  Methionine Restriction Reduces Lung Cancer Pro...
# 38  200239389  Prolyl hydroxylase domain enzyme PHD2 inhibits...
# 39  200272045  Identification of mutant KRAS-related genes as...
#
#                                               Summary       Species  \
# 0   The involvement of γδ TCR-bearing lymphocytes ...  Mus musculus
# 1   The discovery of naïve T cell transcriptional ...  Mus musculus
# 2   Introduction: Advanced cutaneous melanoma is a...  Homo sapiens
# 3   Introduction: Advanced cutaneous melanoma is a...  Homo sapiens
# 4   Despite studies highlighting the prognostic ut...  Homo sapiens
# 5   Prolyl hydroxylase domain protein 2 (PHD2) is ...  Homo sapiens
# 6   Oncogenic KRAS is found in more than 25% of lu...  Homo sapiens
# 7   The biological consequences of various IL-6 gl...  Homo sapiens
# 8   Radiotherapy is an important treatment for non...  Homo sapiens
# 9   Gut microbiota impacts responses to immune che...  Mus musculus
# 10  Chimeric antigen receptor (CAR)-T cell therapy...  Homo sapiens
# 11  Chimeric antigen receptor (CAR)-T cell therapy...  Homo sapiens
# 12  CD70 is an attractive target for chimeric anti...  Homo sapiens
# 13  CD70 is an attractive target for chimeric anti...  Homo sapiens
# 14  The tumor microenvironment presents many obsta...  Homo sapiens
# 15  Introduction: Advanced cutaneous melanoma is a...  Homo sapiens
# 16  Introduction: Advanced cutaneous melanoma is a...  Homo sapiens
# 17  Cultured acute myeloid leukemia (AML) blasts c...  Mus musculus
# 18  Cultured acute myeloid leukemia (AML) blasts c...  Mus musculus
# 19  Cultured acute myeloid leukemia (AML) blasts c...  Mus musculus
# 20  Patients with small-cell lung cancer (SCLC) ar...  Homo sapiens
# 21  Histologic transformation to small cell lung c...  Homo sapiens
# 22  ~12% of SCLCs are marked by the lineage transc...  Homo sapiens
# 23  Small cell lung cancers (SCLC) are comprised o...  Homo sapiens
# 24  The histological transformation of lung adenoc...  Homo sapiens
# 25  An experimental system was designed to screen ...  Homo sapiens
# 26  TGF-β1 is involved in various biological proce...  Homo sapiens
# 27  The base excision repair (BER) Apurinic/apyrim...  Homo sapiens
# 28  Here, we discovered that CoQ10 and its biosynt...  Homo sapiens
# 29  Methionine restriction sensitizes A549 cells w...  Homo sapiens
# 30  The involvement of γδ TCR-bearing lymphocytes ...  Mus musculus
# 31  Anoikis resistance allows cancer cells to avoi...  Homo sapiens
# 32  The discovery of naïve T cell transcriptional ...  Mus musculus
# 33  PTEN binds to and regulates polarization of TA...  Mus musculus
# 34  Intestinal tuft cells are critical in anti-hel...  Mus musculus
# 35  An experimental system was designed to screen ...  Homo sapiens
# 36  We investigated the functional effect of dura-...  Mus musculus
# 37  Methionine restriction sensitizes A549 cells w...  Homo sapiens
# 38  Prolyl hydroxylase domain protein 2 (PHD2) is ...  Homo sapiens
# 39  Oncogenic KRAS is found in more than 25% of lu...  Homo sapiens
#
#     Accession        Date  RelevanceScore  IndividualScore1  IndividualScore2  \
# 0   GSE269394  2024/07/25             1.8                 2               2.0
# 1   GSE261624  2024/07/25             1.5                 1               1.0
# 2   GSE270741  2024/07/24             6.7                 8               8.0
# 3   GSE270740  2024/07/24             6.7                 8               8.0
# 4   GSE270084  2024/07/24             3.0                 3               4.0
# 5   GSE239389  2024/07/17             7.8                 9               7.0
# 6   GSE272045  2024/07/16             8.5                 9               8.0
# 7   GSE269782  2024/07/16             7.0                 6               7.0
# 8   GSE218225  2024/07/12             8.0                 7               8.0
# 9   GSE234818  2024/07/10             9.0                 9               9.0
# 10  GSE272474  2024/07/18             1.0                 1               1.0
# 11  GSE272300  2024/07/18             1.0                 1               1.0
# 12  GSE265937  2024/06/17             1.0                 1               1.0
# 13  GSE227435  2024/06/17             1.0                 1               NaN
# 14  GSE265904  2024/05/30             1.0                 1               1.0
# 15  GSE270741  2024/07/24             6.7                 8               8.0
# 16  GSE270740  2024/07/24             6.7                 8               8.0
# 17  GSE233098  2024/07/23             1.0                 1               1.0
# 18  GSE233097  2024/07/23             1.0                 1               1.0
# 19  GSE233096  2024/07/23             1.0                 1               1.0
# 20  GSE246354  2024/07/16             6.7                 6               6.0
# 21  GSE269746  2024/06/20             8.0                 7               8.0
# 22  GSE249362  2024/06/14             7.7                 8               7.0
# 23  GSE249258  2024/06/14             7.7                 8               7.0
# 24  GSE242843  2024/06/12             5.3                 5               5.0
# 25  GSE271368  2024/07/25             6.3                 6               6.0
# 26  GSE267490  2024/07/24             4.3                 4               4.0
# 27  GSE230874  2024/07/24             2.7                 2               2.0
# 28  GSE229792  2024/07/23             1.7                 1               1.0
# 29  GSE270333  2024/07/19             6.0                 6               6.0
# 30  GSE269394  2024/07/25             1.8                 2               2.0
# 31  GSE267811  2024/07/25             3.0                 3               2.0
# 32  GSE261624  2024/07/25             1.5                 1               1.0
# 33  GSE249265  2024/07/25             4.0                 4               3.0
# 34  GSE241625  2024/07/25             2.7                 3               2.0
# 35  GSE271368  2024/07/25             6.3                 6               6.0
# 36  GSE267325  2024/07/24             3.0                 2               3.0
# 37  GSE270333  2024/07/19             6.0                 6               6.0
# 38  GSE239389  2024/07/17             7.8                 9               7.0
# 39  GSE272045  2024/07/16             8.5                 9               8.0
#
#     IndividualScore3                                     Justification1  \
# 0                2.0  The dataset focuses on γδ T cells and their ro...
# 1                1.0  This dataset examines CD4 T cell responses to ...
# 2                6.0  This dataset investigates TNF-induced dediffer...
# 3                6.0  Similar to the previous dataset, this one expl...
# 4                2.0  This dataset studies DNA methylation patterns ...
# 5                8.0  This dataset focuses on PHD2 in non-small cell...
# 6                9.0  This dataset investigates KRAS mutations in NS...
# 7                8.0  This dataset examines the role of IL-6 glycosy...
# 8                9.0  This dataset investigates radiation resistance...
# 9                9.0  This dataset explores the impact of gut microb...
# 10               1.0  This dataset focuses on CAR T cell therapy for...
# 11               1.0  Similar to the previous dataset, this one also...
# 12               1.0  This dataset investigates CD70-specific CAR T ...
# 13               NaN  This dataset also investigates CD70-specific C...
# 14               1.0  This dataset focuses on CAR T cell therapy in ...
# 15               6.0  This dataset investigates TNF-induced dediffer...
# 16               6.0  Similar to the previous dataset, this one expl...
# 17               1.0  This dataset focuses on acute myeloid leukemia...
# 18               1.0  Similar to the previous dataset, this one also...
# 19               1.0  This dataset investigates acute myeloid leukem...
# 20               8.0  This dataset focuses on small-cell lung cancer...
# 21               9.0  This dataset addresses the transformation of l...
# 22               8.0  This dataset examines POU2F3-positive SCLC and...
# 23               8.0  This dataset explores the regulation of POU2F3...
# 24               6.0  This dataset investigates gene expression chan...
# 25               6.0  This dataset involves RNA-seq of lung cancer m...
# 26               5.0  This dataset examines the effects of TGF-β1 on...
# 27               4.0  This dataset focuses on the DNA-repair protein...
# 28               3.0  This dataset investigates mechanisms in breast...
# 29               6.0  This dataset explores methionine restriction i...
# 30               2.0  The dataset focuses on γδ T cells and their ro...
# 31               4.0  This dataset examines GRP94 in gastric cancer,...
# 32               1.0  This dataset examines CD4 T cell responses to ...
# 33               5.0  This dataset investigates the role of PTEN in ...
# 34               3.0  This dataset explores tuft cell differentiatio...
# 35               6.0  This dataset involves RNA-seq of lung cancer m...
# 36               4.0  This dataset investigates macrophages in lepto...
# 37               6.0  This dataset explores methionine restriction i...
# 38               8.0  This dataset focuses on PHD2 in non-small cell...
# 39               9.0  This dataset investigates KRAS mutations in NS...
#
#                                        Justification2  \
# 0   This dataset investigates γδ T cells in a muri...
# 1   This dataset focuses on CD4 T cells in a mouse...
# 2   This dataset investigates TNF-induced dediffer...
# 3   Similar to the previous dataset, this one expl...
# 4   This dataset analyzes DNA methylation patterns...
# 5   This dataset investigates the role of PHD2 in ...
# 6   This dataset focuses on mutant KRAS in non-sma...
# 7   This dataset explores the role of IL-6 glycosy...
# 8   This dataset examines radiation resistance in ...
# 9   This dataset investigates the impact of gut mi...
# 10  This dataset focuses on CAR T cell therapy in ...
# 11  Similar to dataset 200272474, this dataset inv...
# 12  This dataset focuses on CD70-specific CAR T ce...
# 13                                               None
# 14  This dataset focuses on CAR T cell therapy in ...
# 15  This dataset investigates TNF-induced dediffer...
# 16  Similar to the previous dataset, this one expl...
# 17  This dataset investigates acute myeloid leukem...
# 18  Similar to dataset 200233098, this dataset foc...
# 19  This dataset also investigates acute myeloid l...
# 20  This dataset focuses on small-cell lung cancer...
# 21  This dataset investigates the transformation o...
# 22  This dataset examines POU2F3-positive small ce...
# 23  This dataset explores the regulation of POU2F3...
# 24  This dataset focuses on the gene expression ch...
# 25  This dataset involves RNA-seq of lung cancer m...
# 26  This dataset investigates the effects of TGF-β...
# 27  This dataset focuses on the role of APE1 in mi...
# 28  This dataset examines cancer cell stiffness an...
# 29  This dataset explores methionine restriction i...
# 30  This dataset investigates γδ T cells in a muri...
# 31  This dataset explores the impact of GRP94 knoc...
# 32  This dataset focuses on CD4 T cells in a mouse...
# 33  This dataset examines the role of PTEN in tumo...
# 34  This dataset focuses on the role of Elp3 in in...
# 35  This dataset involves RNA-seq of lung cancer m...
# 36  This dataset investigates macrophage responses...
# 37  This dataset explores methionine restriction i...
# 38  This dataset investigates the role of PHD2 in ...
# 39  This dataset focuses on mutant KRAS in non-sma...
#
#                                        Justification3
# 0   This dataset focuses on γδ T cells and their r...
# 1   This dataset examines CD4 T cells in the conte...
# 2   This dataset investigates TNF-induced dediffer...
# 3   Similar to dataset 200270741, this dataset exp...
# 4   This dataset focuses on DNA methylation patter...
# 5   This dataset investigates the role of PHD2 in ...
# 6   This dataset focuses on mutant KRAS in non-sma...
# 7   This dataset investigates the role of IL-6 gly...
# 8   This dataset examines resistance to radiothera...
# 9   This dataset explores the impact of gut microb...
# 10  This dataset focuses on CAR T-cell therapy in ...
# 11  Similar to the previous dataset, this one inve...
# 12  This dataset focuses on CD70-specific CAR T-ce...
# 13                                               None
# 14  This dataset examines GLUT1 in CAR T-cell ther...
# 15  This dataset investigates TNF-induced dediffer...
# 16  Similar to dataset 200270741, this dataset exp...
# 17  This dataset focuses on acute myeloid leukemia...
# 18  Similar to the previous dataset, this one inve...
# 19  This dataset also focuses on AML and its immun...
# 20  This dataset focuses on small-cell lung cancer...
# 21  This dataset investigates the transformation o...
# 22  This dataset examines POU2F3-positive SCLC and...
# 23  This dataset focuses on the regulation of POU2...
# 24  This dataset explores gene expression changes ...
# 25  This dataset involves RNA-seq of lung cancer m...
# 26  This dataset examines expression changes in re...
# 27  This dataset focuses on APE1 and its role in m...
# 28  This dataset investigates mechanisms in breast...
# 29  This dataset investigates the effects of methi...
# 30  This dataset focuses on γδ T cells and their r...
# 31  This dataset examines GRP94 in gastric cancer,...
# 32  This dataset examines CD4 T cells in the conte...
# 33  This dataset explores the role of PTEN in tumo...
# 34  This dataset focuses on tuft cell differentiat...
# 35  This dataset involves RNA-seq of lung cancer m...
# 36  This dataset examines macrophages in a leptome...
# 37  This dataset investigates the effects of methi...
# 38  This dataset investigates the role of PHD2 in ...
# 39  This dataset focuses on mutant KRAS in non-sma...

# %%
# Test case - full pipeline

result_df = await (main(user_query))
result_df
# Out:
# Raw extracted terms: ['immunotherapies', 'lung cancer']
# Raw expanded terms: ['targeted therapy', 'non-small cell lung cancer', 'immune checkpoint inhibitors', 'small cell lung cancer']
# Raw extracted terms: ['immunotherapies', 'lung cancer']
# Raw expanded terms: ['checkpoint inhibitors', 'NSCLC', 'immune response', 'small cell lung cancer']
# Raw extracted terms: ['immunotherapies', 'lung cancer']
# Raw expanded terms: ['checkpoint inhibitors', 'non-small cell lung cancer', 'immune response', 'squamous cell lung cancer']
# Extracted terms: ['NSCLC AND "gse"[Filter]', 'immunotherapies AND "gse"[Filter]', 'non-small cell lung cancer AND "gse"[Filter]', 'checkpoint inhibitors AND "gse"[Filter]', 'small cell lung cancer AND "gse"[Filter]', 'immune checkpoint inhibitors AND "gse"[Filter]', 'squamous cell lung cancer AND "gse"[Filter]', 'immune response AND "gse"[Filter]', 'targeted therapy AND "gse"[Filter]', 'lung cancer AND "gse"[Filter]']
# Processing GEO IDs in batches: 100%|██████████| 4/4 [00:07<00:00,  1.86s/it]
# Determining dataset relevance: 100%|██████████| 2/2 [00:33<00:00, 16.80s/it]
# Determining dataset relevance: 100%|██████████| 2/2 [00:33<00:00, 16.94s/it]
# Determining dataset relevance: 100%|██████████| 2/2 [00:32<00:00, 16.36s/it]
#            ID                                              Title  \
# 0   200270741  Ceramide metabolism alterations contribute to ...
# 1   200266291  Single cell RNAseq profiling of Human Pancreat...
# 2   200271671  Exosomal miR-194 from adipose-derived stem cel...
# 3   200233096  STAT3 inhibition permits epigenetic reprogramm...
# 4   200261624  Gene expression profile of all CD4 T cells fro...
# 5   200233098  STAT3 inhibition permits epigenetic reprogramm...
# 6   200271086  Personalized dendritic cell vaccine facilitate...
# 7   200242951  Contribution of crosstalk of mesothelial and t...
# 8   200270084  Genome-wide Methylation Patterns in Primary Uv...
# 9   200261186  Serial Changes of Circulating Tumor Cells in P...
# 10  200267325  RNA profiling of CSF resident macrophages and ...
# 11  200269782  Defective N-Glycosylation of IL6 Induces Metas...
# 12  200234818  Faecalibaterium prausnitzii strain EXL01 boost...
# 13  200271672  Exosomal miR-194 from adipose-derived stem cel...
# 14  200234159  Radiation dose heterogeneity primes response t...
# 15  200270333  Methionine Restriction Reduces Lung Cancer Pro...
# 16  200269746  Detecting small cell transformation in patient...
# 17  200249362  Non-Canonical BAF and mSWI/SNF Regulates POU2F...
# 18  200233097  STAT3 inhibition permits epigenetic reprogramm...
# 19  200270740  Ceramide metabolism alterations contribute to ...
# 20  200271085  Personalized dendritic cell vaccine facilitate...
# 21  200241625  Loss of Elp3 impairs the immune response to he...
# 22  200249258  Mammalian SWI/SNF complex activity regulates P...
# 23  200271368  RNA-seq of live cell 3-D models with engineere...
# 24  200234161  Radiation dose heterogeneity primes response t...
# 25  200269394  Long-lived central memory gamma delta T cells ...
# 26  200249265  Transcriptomics of BMDM treated with PTEN in t...
# 27  200239389  Prolyl hydroxylase domain enzyme PHD2 inhibits...
# 28  200246354  GCN2 is a determinant of the response to WEE1 ...
# 29  200267811  Effect of knockdown of GRP94 on gene expressio...
# 30  200272045  Identification of mutant KRAS-related genes as...
# 31  200218225  CRISPR screen of radiation resistant genes in ...
# 32  200273081  Disparate pathways for extrachromosomal DNA bi...
# 33  200242843                  microarray in SCLC transformation
# 34  200223266  Intramyocardial Sprouting Tip Cells Specify Co...
#
#                                               Summary                Species  \
# 0   Introduction: Advanced cutaneous melanoma is a...           Homo sapiens
# 1   Mechanisms driving sex differences across isle...           Homo sapiens
# 2   Hypertrophic scars, which result from aberrant...  Oryctolagus cuniculus
# 3   Cultured acute myeloid leukemia (AML) blasts c...           Mus musculus
# 4   The discovery of naïve T cell transcriptional ...           Mus musculus
# 5   Cultured acute myeloid leukemia (AML) blasts c...           Mus musculus
# 6   Adoptive cell transfer (ACT) using neoantigen-...           Mus musculus
# 7   Tumor metastasis commonly affects pleura in ad...           Homo sapiens
# 8   Despite studies highlighting the prognostic ut...           Homo sapiens
# 9   Background and aims: Immune checkpoint inhibit...           Homo sapiens
# 10  We investigated the functional effect of dura-...           Mus musculus
# 11  The biological consequences of various IL-6 gl...           Homo sapiens
# 12  Gut microbiota impacts responses to immune che...           Mus musculus
# 13  Hypertrophic scars, which result from aberrant...  Oryctolagus cuniculus
# 14  The immunologic effects of radiation (RT) are ...           Mus musculus
# 15  Methionine restriction sensitizes A549 cells w...           Homo sapiens
# 16  Histologic transformation to small cell lung c...           Homo sapiens
# 17  ~12% of SCLCs are marked by the lineage transc...           Homo sapiens
# 18  Cultured acute myeloid leukemia (AML) blasts c...           Mus musculus
# 19  Introduction: Advanced cutaneous melanoma is a...           Homo sapiens
# 20  Adoptive cell transfer (ACT) using neoantigen-...           Mus musculus
# 21  Intestinal tuft cells are critical in anti-hel...           Mus musculus
# 22  Small cell lung cancers (SCLC) are comprised o...           Homo sapiens
# 23  An experimental system was designed to screen ...           Homo sapiens
# 24  This SuperSeries is composed of the SubSeries ...           Mus musculus
# 25  The involvement of γδ TCR-bearing lymphocytes ...           Mus musculus
# 26  PTEN binds to and regulates polarization of TA...           Mus musculus
# 27  Prolyl hydroxylase domain protein 2 (PHD2) is ...           Homo sapiens
# 28  Patients with small-cell lung cancer (SCLC) ar...           Homo sapiens
# 29  Anoikis resistance allows cancer cells to avoi...           Homo sapiens
# 30  Oncogenic KRAS is found in more than 25% of lu...           Homo sapiens
# 31  Radiotherapy is an important treatment for non...           Homo sapiens
# 32  Oncogene amplification on extrachromosomal DNA...           Homo sapiens
# 33  The histological transformation of lung adenoc...           Homo sapiens
# 34  The elaborate patterning of coronary arteries ...           Mus musculus
#
#     Accession        Date  RelevanceScore  IndividualScore1  IndividualScore2  \
# 0   GSE270741  2024/07/24             1.3                 2                 1
# 1   GSE266291  2024/07/25             0.3                 1                 0
# 2   GSE271671  2024/07/24             0.3                 1                 0
# 3   GSE233096  2024/07/23             0.3                 1                 0
# 4   GSE261624  2024/07/25             0.3                 1                 0
# 5   GSE233098  2024/07/23             0.3                 1                 0
# 6   GSE271086  2024/07/05             1.0                 3                 0
# 7   GSE242951  2024/06/26             8.0                 8                 8
# 8   GSE270084  2024/07/24             0.7                 2                 0
# 9   GSE261186  2024/07/17             0.7                 2                 0
# 10  GSE267325  2024/07/24             0.3                 1                 0
# 11  GSE269782  2024/07/16             6.0                 3                 8
# 12  GSE234818  2024/07/10             9.0                 9                 9
# 13  GSE271672  2024/07/24             0.3                 1                 0
# 14  GSE234159  2024/07/12             1.3                 4                 0
# 15  GSE270333  2024/07/19             1.0                 3                 0
# 16  GSE269746  2024/06/20             9.3                 9                 9
# 17  GSE249362  2024/06/14             8.7                 8                 9
# 18  GSE233097  2024/07/23             0.3                 1                 0
# 19  GSE270740  2024/07/24             1.3                 2                 1
# 20  GSE271085  2024/07/05             4.3                 5                 4
# 21  GSE241625  2024/07/25             1.0                 1                 1
# 22  GSE249258  2024/06/14             7.3                 8                 8
# 23  GSE271368  2024/07/25             6.3                 7                 6
# 24  GSE234161  2024/07/12             2.3                 3                 3
# 25  GSE269394  2024/07/25             1.0                 1                 1
# 26  GSE249265  2024/07/25             4.7                 5                 5
# 27  GSE239389  2024/07/17             8.7                 9                 9
# 28  GSE246354  2024/07/16             7.7                 8                 8
# 29  GSE267811  2024/07/25             1.0                 1                 1
# 30  GSE272045  2024/07/16             9.7                10                10
# 31  GSE218225  2024/07/12             7.0                 6                 7
# 32  GSE273081  2024/07/25             1.7                 2                 2
# 33  GSE242843  2024/06/12             3.7                 4                 3
# 34  GSE223266  2024/07/25             1.0                 1                 1
#
#     IndividualScore3                                     Justification1  \
# 0                  1  Attempt 1: Score 2 - This dataset focuses on m...
# 1                  0  Attempt 1: Score 1 - This dataset examines pan...
# 2                  0  Attempt 1: Score 1 - The study investigates hy...
# 3                  0  Attempt 1: Score 1 - This dataset focuses on a...
# 4                  0  Attempt 1: Score 1 - This dataset studies CD4 ...
# 5                  0  Attempt 1: Score 1 - Similar to the previous d...
# 6                  0  Attempt 1: Score 3 - This dataset discusses th...
# 7                  8  Attempt 1: Score 8 - This dataset is highly re...
# 8                  0  Attempt 1: Score 2 - This dataset relates to u...
# 9                  0  Attempt 1: Score 2 - This dataset involves hep...
# 10                 0  Attempt 1: Score 1 - This dataset studies macr...
# 11                 7  Attempt 1: Score 3 - This dataset investigates...
# 12                 9  Attempt 1: Score 9 - This dataset is extremely...
# 13                 0  Attempt 1: Score 1 - This dataset focuses on h...
# 14                 0  Attempt 1: Score 4 - This dataset examines the...
# 15                 0  Attempt 1: Score 3 - This dataset discusses me...
# 16                10  Attempt 1: Score 9 - This dataset focuses on d...
# 17                 9  Attempt 1: Score 8 - This dataset investigates...
# 18                 0  Attempt 1: Score 1 - This dataset focuses on A...
# 19                 1  Attempt 1: Score 2 - This dataset discusses ce...
# 20                 4  Attempt 1: Score 5 - This dataset focuses on a...
# 21                 1  Attempt 1: Score 1 - This dataset investigates...
# 22                 6  Attempt 1: Score 8 - This dataset explores the...
# 23                 6  Attempt 1: Score 7 - This dataset involves RNA...
# 24                 1  Attempt 1: Score 3 - This dataset discusses ra...
# 25                 1  Attempt 1: Score 1 - This dataset focuses on γ...
# 26                 4  Attempt 1: Score 5 - This dataset examines the...
# 27                 8  Attempt 1: Score 9 - This dataset investigates...
# 28                 7  Attempt 1: Score 8 - This dataset explores the...
# 29                 1  Attempt 1: Score 1 - This dataset examines the...
# 30                 9  Attempt 1: Score 10 - This dataset identifies ...
# 31                 8  Attempt 1: Score 6 - This dataset involves a C...
# 32                 1  Attempt 1: Score 2 - This dataset explores ext...
# 33                 4  Attempt 1: Score 4 - This dataset studies gene...
# 34                 1  Attempt 1: Score 1 - This dataset focuses on c...
#
#                                        Justification2  \
# 0   Attempt 2: Score 1 - This dataset focuses on m...
# 1   Attempt 2: Score 0 - This dataset investigates...
# 2   Attempt 2: Score 0 - The study focuses on hype...
# 3   Attempt 2: Score 0 - This dataset examines acu...
# 4   Attempt 2: Score 0 - This dataset focuses on C...
# 5   Attempt 2: Score 0 - Similar to ID 200233096, ...
# 6   Attempt 2: Score 0 - This dataset discusses de...
# 7   Attempt 2: Score 8 - This dataset directly inv...
# 8   Attempt 2: Score 0 - This dataset focuses on u...
# 9   Attempt 2: Score 0 - This dataset studies circ...
# 10  Attempt 2: Score 0 - This dataset investigates...
# 11  Attempt 2: Score 8 - This dataset explores IL-...
# 12  Attempt 2: Score 9 - This dataset examines the...
# 13  Attempt 2: Score 0 - This dataset focuses on h...
# 14  Attempt 2: Score 0 - This dataset studies the ...
# 15  Attempt 2: Score 0 - This dataset focuses on m...
# 16  Attempt 2: Score 9 - This dataset investigates...
# 17  Attempt 2: Score 9 - This dataset focuses on t...
# 18  Attempt 2: Score 0 - Similar to ID 200233096, ...
# 19  Attempt 2: Score 1 - This dataset discusses me...
# 20  Attempt 2: Score 4 - This dataset focuses on a...
# 21  Attempt 2: Score 1 - While this dataset discus...
# 22  Attempt 2: Score 8 - This dataset investigates...
# 23  Attempt 2: Score 6 - This dataset involves RNA...
# 24  Attempt 2: Score 3 - This dataset discusses ra...
# 25  Attempt 2: Score 1 - This dataset focuses on γ...
# 26  Attempt 2: Score 5 - This dataset explores the...
# 27  Attempt 2: Score 9 - This dataset examines the...
# 28  Attempt 2: Score 8 - This dataset investigates...
# 29  Attempt 2: Score 1 - This dataset focuses on G...
# 30  Attempt 2: Score 10 - This dataset identifies ...
# 31  Attempt 2: Score 7 - This dataset involves a C...
# 32  Attempt 2: Score 2 - This dataset discusses ex...
# 33  Attempt 2: Score 3 - This dataset examines gen...
# 34  Attempt 2: Score 1 - This dataset focuses on c...
#
#                                        Justification3
# 0   Attempt 3: Score 1 - This dataset focuses on m...
# 1   Attempt 3: Score 0 - This dataset investigates...
# 2   Attempt 3: Score 0 - This dataset focuses on h...
# 3   Attempt 3: Score 0 - This dataset studies acut...
# 4   Attempt 3: Score 0 - This dataset examines CD4...
# 5   Attempt 3: Score 0 - Similar to ID 200233096, ...
# 6   Attempt 3: Score 0 - This dataset discusses de...
# 7   Attempt 3: Score 8 - This dataset directly inv...
# 8   Attempt 3: Score 0 - This dataset focuses on u...
# 9   Attempt 3: Score 0 - This dataset studies circ...
# 10  Attempt 3: Score 0 - This dataset investigates...
# 11  Attempt 3: Score 7 - This dataset explores IL-...
# 12  Attempt 3: Score 9 - This dataset examines the...
# 13  Attempt 3: Score 0 - This dataset focuses on h...
# 14  Attempt 3: Score 0 - This dataset investigates...
# 15  Attempt 3: Score 0 - This dataset focuses on m...
# 16  Attempt 3: Score 10 - This dataset provides in...
# 17  Attempt 3: Score 9 - This dataset explores POU...
# 18  Attempt 3: Score 0 - Similar to ID 200233096, ...
# 19  Attempt 3: Score 1 - This dataset discusses me...
# 20  Attempt 3: Score 4 - This dataset focuses on i...
# 21  Attempt 3: Score 1 - While this dataset discus...
# 22  Attempt 3: Score 6 - This dataset investigates...
# 23  Attempt 3: Score 6 - This dataset involves RNA...
# 24  Attempt 3: Score 1 - This dataset discusses ra...
# 25  Attempt 3: Score 1 - This dataset focuses on γ...
# 26  Attempt 3: Score 4 - This dataset explores the...
# 27  Attempt 3: Score 8 - This dataset investigates...
# 28  Attempt 3: Score 7 - This dataset examines the...
# 29  Attempt 3: Score 1 - This dataset focuses on G...
# 30  Attempt 3: Score 9 - This dataset identifies g...
# 31  Attempt 3: Score 8 - This dataset investigates...
# 32  Attempt 3: Score 1 - This dataset focuses on e...
# 33  Attempt 3: Score 4 - This dataset examines gen...
# 34  Attempt 3: Score 1 - This dataset focuses on c...

# %%
result_df.to_csv("../results/2024_07_25_DetermineDatasetRelevance/DatasetRelevance_MultipleScores.csv")
